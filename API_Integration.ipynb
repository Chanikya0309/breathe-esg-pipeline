# %% [markdown]
# OpenAI SDK

# %%
import os
from dotenv import load_dotenv

load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

assert OPENAI_API_KEY is not None, "OPENAI_API_KEY is not set"
print("OPENAI_API_KEY is set successfully.")
# Out:
# OPENAI_API_KEY is set successfully.

# %%
import requests

url  = "https://api.openai.com/v1/chat/completions"
headers = {
    "Authorization": f"Bearer {OPENAI_API_KEY}",
    "Content-Type": "application/json"
}

body = {
    "model": "gpt-4o-mini",
    "messages": [
        {"role":"system", "content": "You are a helpful assistant."},
        {"role":"user", "content": "Who is the chief minister of Tamil Nadu?"}
    ],
}

response = requests.post(url, headers=headers, json=body, timeout=30)
print(response)
# Out:
# <Response [429]>

# %% [markdown]
# GROQ SDK

# %%
import os
from dotenv import load_dotenv

# This loads the variables from your .env file into the system environment
load_dotenv()

GROQ_API_KEY = os.getenv("GROQ_API_KEY")
assert GROQ_API_KEY is not None, "GROQ_API_KEY is not set"
print("GROQ_API_KEY is set successfully.")
# Out:
# GROQ_API_KEY is set successfully.

# %%
import os
from groq import Groq

client = Groq()

response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {
            "role": "user",
            "content": "What is the capital of India?"
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# The capital of India is New Delhi.

# %%
from openai import OpenAI
groq_client = OpenAI(
    api_key = GROQ_API_KEY,
    base_url = "https://api.groq.com/openai/v1",
)

response = groq_client.chat.completions.create(
    model = "llama-3.1-8b-instant",
    messages = [
        { "role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "What is API?"}
    ],
)

print(response.choices[0].message.content)
# Out:
# API stands for Application Programming Interface. It's a set of defined rules that enable different software systems, applications, or services to communicate with each other and exchange data. In simpler terms, an API is like a messenger that allows various systems to talk to each other.
#
# Imagine you're at a restaurant, and you want to order food. You can't just go into the kitchen and start making your own food. But, you can give your order to the waiter, and they'll take it to the kitchen staff. The waiter acts as an intermediary between you and the kitchen, ensuring that your order is fulfilled accurately.
#
# An API works similarly:
#
# 1. **Request**: A client (like your web browser or mobile app) sends a request to the server (like a restaurant) with specific instructions.
# 2. **Processing**: The server processes the request and sends the required data or response back to the client.
# 3. **Response**: The client receives the response from the server, which contains the requested data or information.
#
# APIs are commonly used in various industries, such as:
#
# 1. **Web development**: APIs allow different web applications to share data and functionality.
# 2. **Mobile apps**: APIs enable mobile apps to access cloud services, such as social media, email, or maps.
# 3. **Cloud computing**: APIs allow users to interact with cloud services, such as AWS, Google Cloud, or Microsoft Azure.
# 4. **Machine learning**: APIs enable developers to access AI and ML models for tasks like image recognition, natural language processing, or predictive analytics.
#
# Some popular examples of APIs include:
#
# 1. **Google Maps API**: Provides map data and directions to developers.
# 2. **Facebook API**: Allows developers to access user data and services.
# 3. **Twilio API**: Enables developers to build voice and SMS applications.
# 4. **Stripe API**: Provides payment processing services for e-commerce platforms.
#
# In summary, APIs enable seamless communication between different systems, applications, and services, making it possible to access data, functionality, and services from various sources.

# %%
from openai import OpenAI
groq_client = OpenAI(
    api_key = GROQ_API_KEY,
    base_url = "https://api.groq.com/openai/v1",
)

response = groq_client.chat.completions.create(
    model = "llama-3.3-70b-versatile",
    messages = [
        { "role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "What is API?"}
    ],
)

print(response.choices[0].message.content)
# Out:
# **API Definition:**
# An API, or Application Programming Interface, is a set of defined rules that enables different software systems to communicate with each other. It allows data to be exchanged, processed, and manipulated between systems, enabling them to work together seamlessly.
#
# **Key Characteristics:**
#
# 1. **Interoperability**: APIs enable different systems, languages, and platforms to interact with each other.
# 2. **Standardization**: APIs follow standardized protocols and formats, ensuring consistency and reliability.
# 3. **Abstraction**: APIs hide the complexity of underlying systems, providing a simplified interface for interaction.
# 4. **Reusability**: APIs can be reused across multiple applications and systems, reducing development time and costs.
#
# **API Types:**
#
# 1. **Web API**: Uses HTTP protocols to interact with web-based systems.
# 2. **Operating System API**: Interacts with the operating system to access hardware and software resources.
# 3. **Library API**: Provides a set of pre-built functions and classes for use in software development.
#
# **API Uses:**
#
# 1. **Data Integration**: APIs enable data exchange between systems, facilitating integration and synchronization.
# 2. **Microservices Architecture**: APIs connect individual microservices, allowing them to work together as a cohesive system.
# 3. **Third-Party Integrations**: APIs enable integration with external services, such as payment gateways, social media platforms, and more.
# 4. **Mobile and Web Applications**: APIs power mobile and web applications, providing access to data, functionality, and services.
#
# In summary, APIs are a crucial component of modern software development, enabling systems to interact, exchange data, and work together efficiently.
